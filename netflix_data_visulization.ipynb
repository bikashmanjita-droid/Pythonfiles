# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("netflix_5000_rows.csv")

# %%
df.isnull().sum()
# Out:
# show_id             0
# type                0
# title               1
# director         1489
# cast                0
# country             0
# data_added          0
# released_year       0
# rating              0
# duration            0
# listed in           0
# discription         0
# dtype: int64

# %%
df=df.dropna(subset=['title', 'director'])

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# data_added       0
# released_year    0
# rating           0
# duration         0
# listed in        0
# discription      0
# dtype: int64

# %%
df.head()
# Out:
#   show_id     type                        title         director  \
# 0  s00000    Movie                  State place     Stacey Hines
# 2  s00002  TV Show              Score boy smile   Jessica Watson
# 3  s00003    Movie                  Life result  Katherine Kelly
# 5  s00005  TV Show  Now prepare democratic help      Heidi Smith
# 6  s00006  TV Show                 World relate       Wendy Tate
#
#                                                 cast        country  \
# 0        Manuel Estrada, Peter Flores, Jamie Wilkins         Brazil
# 2                      Michelle Dyer, Cristina Rivas      Venezuela
# 3                  Richard Colon, Christina Matthews  Guinea-Bissau
# 5                  Timothy Gilbert, Joseph Gallagher          Malta
# 6  Michael Daniel, Rebecca Peters, Rebecca Terry,...           Fiji
#
#          data_added  released_year rating     duration           listed in  \
# 0    March 01, 2024           1997  TV-MA       96 min       Documentaries
# ...

# %%
#Collecting the index and values to visulize the data
shows_counts=df['type'].value_counts()
rating_count=df['rating'].value_counts()
listed_count=df['listed in'].value_counts()
release_year_count=df['released_year'].value_counts()

#Making subplots of all data to spect
fig, ax= plt.subplots(5,1 , figsize=(5,20))

#making bars of tv shows and movies
ax[0]. bar(shows_counts.index, shows_counts.values, color=['purple', 'skyblue'], width=0.1)
ax[0].set_title("The numbrs of Tv shows vs Movies")
ax[0].set_xlabel("Shows Types")
ax[0].set_ylabel("counts")

#pie-chart in the basis of rating
ax[1].pie(rating_count.values, labels=rating_count.index,  autopct='%1.1f%%')
ax[1].set_title("Rating of movies of tv_shows in pie-chart")

#pie-chart in the basis of catoferis of tv-shows and movies
ax[2].pie(listed_count.values, labels=listed_count.index,  autopct='%1.1f%%')
ax[2].set_title("Catogeris of shows")

#scatter of the numbers of released movies with the repect ot years
ax[3].scatter(release_year_count.index, release_year_count.values, color='blue', marker='o')
ax[3].set_title("The Scatter of release of movies date")
ax[3].set_xlabel("Years")
ax[3].set_ylabel("The numbe of released movies")

#the high amount of producing movies in top-10 countries
ax[4].barh(country_counts.index[:10], country_counts.values[:10], color='green')
ax[4].set_title("The curve of high movies producing countries")
ax[4].set_xlabel("countries")
ax[4].set_ylabel("The number of movies")


#making appropiate canvas for the graphs
plt.tight_layout()

#saving the graphs in the local file
plt.savefig("netflix_subplots_graph.png", dpi=300, bbox_inches='tight' )
plt.show()
